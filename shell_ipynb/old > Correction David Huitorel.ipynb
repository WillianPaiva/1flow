# %%
#http://blog.davidhuitorel.com/
from oneflow.core.models import *
import requests

# %%
davids = Feed.objects.get(id='51c66184e7a05b27f68ce450').all_articles.no_cache()

# %%
davids.count()
# Out:
# 64

# %%
for article in davids:
    print article.url
# Out:
# http://www.davidhuitorelblog.com/amelie-etienne-mariage201/
# http://www.davidhuitorelblog.com/les-presque/
# http://www.davidhuitorelblog.com/david-sarra-after-the-day/
# http://blog.davidhuitorel.com/les-presque/
# http://blog.davidhuitorel.com/david-sarra-after-the-day/
# http://www.davidhuitorelblog.com/photogadiamb-guillaume-ombline/
# http://www.davidhuitorelblog.com/lynda-frantz-st-joseph/
# http://www.davidhuitorelblog.com/sandrine-james-mariage-ile-maurice-3/
# http://www.davidhuitorelblog.com/lucie-yann-le-rogaton/
# http://www.davidhuitorelblog.com/lucie-yann-mariage-suite-le-mini-studio/
# http://www.davidhuitorelblog.com/lucie-yann-mariage-petite-ile-reunion/
# http://www.davidhuitorelblog.com/audrey-thierry-engagement/
# http://www.davidhuitorelblog.com/mariage-rocknroll/
# http://www.davidhuitorelblog.com/photographier-un-mariage-avec-un-iphone/
# http://www.davidhuitorelblog.com/lucie-yann-engagement/
# http://blog.davidhuitorel.com/?p=706
# ...

# %%
r = requests.get('http://www.davidhuitorelblog.com/amelie-etienne-mariage201/')
# Out:
# Starting new HTTP connection (1): www.davidhuitorelblog.com
# "GET /amelie-etienne-mariage201/ HTTP/1.1" 200 7951

# %%
r.content
# Out:
# '<!DOCTYPE html>\n<html lang="fr-FR"><!-- p4 build #1294  -->\n<head>\n\t<title>mariage d\'amelie et etienne | david huitorel - photographe sur l&#039;ile de la reunion, paris et centre bretagne - photojournaliste de mariage</title>\n\t<meta charset="UTF-8" />\n\t<meta http-equiv="imagetoolbar" content="no" />\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n\t<meta name="keywords" content="c\xc3\xa9r\xc3\xa9monie laique, golf du bassin bleu, l\'ile de la reunion, Mariage, wedding planner, zotmariage.re, david huitorel, photographe, photographie, photo" />\n\t<meta property="og:site_name" content="david huitorel &#8211; photographe sur l&#039;ile de la reunion, paris et centre bretagne &#8211; photojournaliste de mariage" />\n\t<meta property="og:type" content="article" />\n\t<meta property="og:title" content="Amelie + Etienne &#8211; St Gilles les Hauts" />\n\t<meta property="og:url" content="http://www.davidhuitorelblog.com/amelie-etienne-mariage201/" />\n\t<meta propert
# ...
